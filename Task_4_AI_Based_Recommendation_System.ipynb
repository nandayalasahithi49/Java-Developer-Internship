# %%
java_code = """
import java.util.*;

public class RecommendationSystem {

    public static void main(String[] args) {

        Map<String, Integer> products = new HashMap<>();

        products.put("Laptop", 5);
        products.put("Mobile", 4);
        products.put("Headphones", 3);
        products.put("Smart Watch", 5);
        products.put("Keyboard", 2);

        System.out.println("Recommended Products:");

        products.entrySet()
                .stream()
                .filter(product -> product.getValue() >= 4)
                .sorted((a, b) -> b.getValue() - a.getValue())
                .forEach(product ->
                        System.out.println(product.getKey()
                                + " Rating: "
                                + product.getValue()));
    }
}
"""
with open("RecommendationSystem.java", "w") as f:
    f.write(java_code)

print("RecommendationSystem.java created")
# Out:
# RecommendationSystem.java created

# %%
# !javac RecommendationSystem.java

# %%
# !java RecommendationSystem
# Out:
# Recommended Products:
# Laptop Rating: 5
# Smart Watch Rating: 5
# Mobile Rating: 4

# %%
readme = """
# Task 4 - AI Based Recommendation System

This Java project demonstrates a simple recommendation system.

Features:
- Stores product ratings
- Recommends highly rated products
- Displays recommendations in sorted order

Files:
- RecommendationSystem.java
"""

with open("README.md", "w") as f:
    f.write(readme)

print("README.md created successfully!")
# Out:
# README.md created successfully!

# %%
from google.colab import files

files.download("RecommendationSystem.java")
files.download("README.md")
